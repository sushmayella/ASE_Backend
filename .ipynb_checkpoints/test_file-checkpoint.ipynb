# %% [markdown]
# ### Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.models import load_model

# %% [markdown]
# ### Model Loading

# %%
model=load_model("models/DenseNet201_model.h5")

# %%
class_labels={0:'Apple___Apple_scab', 
              1:'Apple___Black_rot', 
              2:'Apple___Cedar_apple_rust', 
              3:'Apple___healthy'}

# %% [markdown]
# ### User input

# %%
filepath="input/val/rot/rot (55).JPG"

# %%
image=load_img(filepath, grayscale=False, color_mode='rgb', target_size=(256,256))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
image=img_to_array(image)
image=image/255.0
expanded_image=np.expand_dims(image,axis=0)

# %%
model_prediction=model.predict(expanded_image,verbose=1)
print(model_prediction)
# Out:
# 1/1 [==============================] - 0s 252ms/step
# [[1.10963265e-04 9.99888897e-01 1.18886170e-07 3.45872913e-08]]

# %%
print(f"model predicted class is -> {np.argmax(model_prediction[0])}")
print(f"model predicted label is -> {class_labels[np.argmax(model_prediction[0])]}")
print(f"model probability score is -> {model_prediction[0][np.argmax(model_prediction[0])]}%")
# Out:
# model predicted class is -> 1
# model predicted label is -> Apple___Black_rot
# model probability score is -> 0.9998888969421387%

# %% [markdown]
# ---
